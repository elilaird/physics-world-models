# %% [markdown]
# # 05 - Results Analysis
#
# Comprehensive analysis of all experiments:
# - Baseline vs learned model comparison
# - Architecture accuracy-size tradeoff
# - Quantization impact visualization
# - Final deployment recommendations

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

from src.data.visualization import plot_model_comparison

# %matplotlib inline
sns.set_style('whitegrid')

# %%
# Load experiment results
results_dir = Path('results')

if (results_dir / 'architecture_search' / 'architecture_comparison.json').exists():
    with open(results_dir / 'architecture_search' / 'architecture_comparison.json') as f:
        arch_results = json.load(f)
    print('Architecture search results loaded')
    for name, r in arch_results.items():
        print(f'  {name}: {r["total_params"]:,} params, '
              f'{r["model_size_int8_mb"]:.3f} MB (INT8), '
              f'{r["median_latency_ms"]:.2f} ms')
else:
    print('No architecture search results found. Run experiments/architecture_search.py first.')
